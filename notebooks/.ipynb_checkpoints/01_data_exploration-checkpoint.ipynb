# %%
import pandas as pd
#carichiamo il dataset
df=pd.read_csv("../data/human_performance_dataset.csv")
#stampiamo le variabili
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975425 entries, 0 to 975424
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   step                         975425 non-null  int64
#  1   trajectory_id                975425 non-null  int64
#  2   regime                       975425 non-null  object
#  3   reaction_time                975425 non-null  float64
#  4   error_rate                   975425 non-null  float64
#  5   motivation                   975425 non-null  float64
#  6   timestamp                    975425 non-null  object
#  7   task_type                    975425 non-null  object
#  8   task_difficulty              975425 non-null  float64
#  9   time_pressure                975425 non-null  object
#  10  error_severity               975425 non-null  object
#  11  downstream_cost              975425 non-null  int64
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of         step  trajectory_id  regime  reaction_time  error_rate  motivation  \
# 0          0              0  NORMAL     409.990811    0.064074    8.271224
# 1          1              0  NORMAL     604.333789    0.063963    6.984834
# 2          2              0  NORMAL     549.450027    0.064438    6.230788
# 3          3              0  NORMAL     479.728081    0.065361    5.936007
# 4          4              0  NORMAL     565.509924    0.064799    4.890426
# ...      ...            ...     ...            ...         ...         ...
# 975420  6996            139  NORMAL     149.999008    0.013292    9.086730
# 975421  6997            139  NORMAL     149.999242    0.012990    9.962610
# 975422  6998            139  NORMAL     149.998793    0.010021    8.098482
# 975423  6999            139  NORMAL     150.000221    0.013316    9.038611
# 975424  7000            139  NORMAL     150.000309    0.009311    9.999293
#
# ...

# %%
df.describe()
# Out:
#                 step  trajectory_id  reaction_time     error_rate  \
# count  975425.000000  975425.000000  975425.000000  975425.000000
# mean     3507.044684      69.419534     430.135907       0.048379
# std      2022.034080      40.442515     286.877214       0.034272
# min         0.000000       0.000000     149.995311       0.005000
# 25%      1755.000000      34.000000     194.307161       0.019523
# 50%      3513.000000      69.000000     364.568313       0.041124
# 75%      5259.000000     104.000000     568.840590       0.069206
# max      7000.000000     139.000000    3000.002002       0.352274
#
#           motivation  task_difficulty  downstream_cost     risk_score  \
# count  975425.000000    975425.000000    975425.000000  975425.000000
# mean        6.241226         0.624852       169.410360      32.654896
# std         2.900157         0.163074       686.605003      11.939030
# min         0.000000         0.300155         0.000000      10.174011
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Impostiamo uno stile pulito per i grafici
sns.set_theme(style="whitegrid")

# %%
# Prepariamo una "tela" larga 10 pollici e alta 6
plt.figure(figsize=(10, 6))

# Disegniamo l'istogramma dei tempi di reazione
sns.histplot(df['reaction_time'], bins=50, color='royalblue', kde=True)

# Diamo un titolo e i nomi agli assi
plt.title('Distribuzione dei Tempi di Reazione')
plt.xlabel('Tempo di reazione (ms)')
plt.ylabel('Frequenza (numero di osservazioni)')

# Mostriamo il risultato a schermo
plt.show()

# %%
# Prepariamo una tela un po' più piccola
plt.figure(figsize=(8, 5))

# Creiamo il grafico a barre per la colonna 'regime'
sns.countplot(data=df, x='regime', hue='regime', palette='Set2', legend=False)
# Aggiungiamo i titoli
plt.title('Frequenza degli Stati Psicofisici (Regime)')
plt.xlabel('Stato dell\'Agente')
plt.ylabel('Numero di Osservazioni')

# Mostriamo il grafico
plt.show()
